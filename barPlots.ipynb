# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
nb_maps = 3
algo = ["DFS", "BFS", "Greedy Search", "A*"]
nb_algo = len(algo)
run_times = np.random.rand(3, 4)
run_times
# Out:
# array([[8.77634727e-01, 7.37404619e-02, 9.30821330e-01, 1.67286959e-01],
#        [4.01652288e-01, 7.88228139e-01, 9.92312005e-01, 3.92483279e-01],
#        [1.47108909e-04, 1.61870183e-01, 1.61223128e-01, 5.30205119e-01]])

# %%
plt.figure(figsize=(16, 10))
plt.title("Running times of different search algorithms")
plt.xlabel("Maps")
plt.ylabel("Running time (s)")

bar_width = .5
bar_positions = np.arange(nb_maps)*bar_width*(nb_algo+1)

for i in range(nb_algo):
    plt.bar(bar_positions+bar_width*i, run_times[:, i], width=bar_width)

plt.xticks(bar_positions+(nb_algo-1)/2*bar_width, ["Map %d" % i for i in range(nb_maps)])
plt.legend(["%s" % i for i in (algo)])

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
nb_maps = 3
maps = ["Small", "Medium", "Large"]
algo = ["DFS", "BFS", "Greedy Search", "A*"]
nb_algo = len(algo)
run_times = np.random.rand(3, 4)
run_times
# Out:
# array([[0.3127417 , 0.69850325, 0.95709446, 0.56945976],
#        [0.87978727, 0.22922995, 0.65969967, 0.24933584],
#        [0.41745203, 0.52434638, 0.75371876, 0.77930206]])

# %%
plt.figure(figsize=(16, 10))
plt.title("Running times of different search algorithms")
plt.xlabel("Maps")
plt.ylabel("Running time (s)")

bar_width = .5
bar_positions = np.arange(nb_maps)*bar_width*(nb_algo+1)

for i in range(nb_algo):
    plt.bar(bar_positions+bar_width*i, run_times[:, i], width=bar_width)

plt.xticks(bar_positions+(nb_algo-1)/2*bar_width, ["%s" % i for i in (maps)])
plt.legend(["%s" % i for i in (algo)])
plt.savefig("barplots.png")
